# %%
from flask import Flask, render_template
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from io import BytesIO
import base64

# %%
playstore = pd.read_csv('data/googleplaystore.csv')
playstore
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
playstore = playstore.drop_duplicates(subset = "App", keep= "first")
playstore.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
playstore = playstore.drop([10472])
playstore.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
playstore.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
playstore['Category'] = playstore['Category'].astype('category')
playstore.dtypes
# Out:
# App                 object
# Category          category
# Rating             float64
# Reviews             object
# Size                object
# Installs            object
# Type                object
# Price               object
# Content Rating      object
# Genres              object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# dtype: object

# %%
playstore.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
playstore['Installs'] = playstore['Installs'].apply(lambda x: x.replace(',', ''))
playstore['Installs'] = playstore['Installs'].apply(lambda x: x.replace('+', ''))
playstore.dtypes
# Out:
# App                 object
# Category          category
# Rating             float64
# Reviews             object
# Size                object
# Installs            object
# Type                object
# Price               object
# Content Rating      object
# Genres              object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# dtype: object

# %%
playstore['Installs'] = playstore['Installs'].astype('int')
playstore.dtypes
# Out:
# App                 object
# Category          category
# Rating             float64
# Reviews             object
# Size                object
# Installs             int32
# Type                object
# Price               object
# Content Rating      object
# Genres              object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# dtype: object

# %%
playstore['Size'] = playstore['Size'].replace('Varies with device', np.nan) 
playstore.Size = (playstore.Size.replace(r'[kM]+$', '', regex=True).astype(float) * \
             playstore.Size.str.extract(r'[\d\.]+([KM]+)', expand=False)
            .fillna(1)
            .replace(['k','M'], [10**3, 10**6]).astype(int))
playstore['Size'] = playstore['Size'].fillna(playstore.groupby('Category')['Size'].transform('mean'))
playstore
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
playstore['Price'] = playstore['Price'].apply(lambda x: x.replace('$', ''))
playstore
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
playstore['Price'] = playstore['Price'].astype('float')
playstore.dtypes
# Out:
# App                 object
# Category          category
# Rating             float64
# Reviews             object
# Size               float64
# Installs             int32
# Type                object
# Price              float64
# Content Rating      object
# Genres              object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# dtype: object

# %%
playstore[['Reviews', 'Size', 'Installs']] = playstore[['Reviews', 'Size', 'Installs']].astype('int')
playstore.dtypes
# Out:
# App                 object
# Category          category
# Rating             float64
# Reviews              int32
# Size                 int32
# Installs             int32
# Type                object
# Price              float64
# Content Rating      object
# Genres              object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# dtype: object

# %%
df2 = playstore.copy()

# %%
df2.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews      Size  Installs  Type  Price Content Rating  \
# 0      159  19000000     10000  Free    0.0       Everyone
# 1      967  14000000    500000  Free    0.0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
top_category = pd.crosstab(index=df2['Category'],
           columns='Jumlah').sort_values(by = 'Jumlah',ascending = False).head().reset_index()
top_category.head()
# Out:
# col_0  Category  Jumlah
# 0        FAMILY    1832
# 1          GAME     959
# 2         TOOLS     827
# 3      BUSINESS     420
# 4       MEDICAL     395

# %%
most_category = top_category.Category[0]
most_category
# Out:
# 'FAMILY'

# %%
total = top_category.Jumlah[0]
total
# Out:
# 1832

# %%
rev_table = df2[['Category','App','Reviews', 'Rating']].groupby(['Category','App']).sum().sort_values(by = 'Reviews', ascending = False).head(10).reset_index()
rev_table
# Out:
#         Category                                                App  \
# 0         SOCIAL                                           Facebook
# 1  COMMUNICATION                                 WhatsApp Messenger
# 2         SOCIAL                                          Instagram
# 3  COMMUNICATION           Messenger – Text and Video Chat for Free
# 4           GAME                                     Clash of Clans
# 5          TOOLS            Clean Master- Space Cleaner & Antivirus
# 6           GAME                                     Subway Surfers
# 7  VIDEO_PLAYERS                                            YouTube
# 8          TOOLS  Security Master - Antivirus, VPN, AppLock, Boo...
# 9           GAME                                       Clash Royale
#
#       Reviews  Rating
# 0  78158306.0     4.1
# 1  69119316.0     4.4
# 2  66577313.0     4.5
# 3  56642847.0     4.0
# 4  44891723.0     4.6
# 5  42916526.0     4.7
# 6  27722264.0     4.5
# 7  25655305.0     4.3
# ...

# %%
cat_order = df2.groupby('Category').agg({
    'Category' : 'count'
        }).rename({'Category':'Total'}, axis=1).sort_values(by='Total', ascending=False).head(5).reset_index()
x = cat_order['Category'].values
y = cat_order['Total'].values
my_colors = 'rgbmcy'
fig = plt.figure(figsize=(6,3), dpi=300)
fig.add_subplot()
plt.barh(x,y, color=my_colors,height=0.9)
plt.savefig('cat_order.png',bbox_inches="tight")

# %%
x = df2['Reviews'].values
y = df2['Rating'].values
area_size = playstore['Installs'].values/10000000
fig = plt.figure(figsize=(5,5))
fig.add_subplot()
plt.scatter(x,y, s=area_size, alpha=0.3)
plt.xlabel('Reviews')
plt.ylabel('Rating')
plt.savefig('rev_rat.png',bbox_inches="tight")

# %%
x= (df2['Size']/1000000).values
fig = plt.figure(figsize=(5,5))
fig.add_subplot()
plt.hist(x,100, density=True,  alpha=0.75)
plt.xlabel('Size')
plt.ylabel('Frequency')
plt.savefig('hist_size.png',bbox_inches="tight")

# %%
price_table = df2[['Category','App','Installs','Price']].groupby(['Category','App']).sum().sort_values(by = 'Price', ascending = False).head(10).reset_index()
price_table
# Out:
#     Category                             App  Installs   Price
# 0  LIFESTYLE        I'm Rich - Trump Edition   10000.0  400.00
# 1  LIFESTYLE                      💎 I'm rich   10000.0  399.99
# 2     FAMILY          most expensive app (H)     100.0  399.99
# 3    FINANCE              I am rich(premium)    5000.0  399.99
# 4    FINANCE  I am rich (Most expensive app)    1000.0  399.99
# 5    FINANCE                      I am Rich!    1000.0  399.99
# 6    FINANCE                       I am Rich    5000.0  399.99
# 7    FINANCE               I Am Rich Premium   50000.0  399.99
# 8    FINANCE              I AM RICH PRO PLUS    1000.0  399.99
# 9     FAMILY                  I am Rich Plus   10000.0  399.99

# %%
x = price_table['App'].values
y = price_table['Price'].values
my_colors = 'rgbmcy'
fig = plt.figure(figsize=(6,3), dpi=300)
fig.add_subplot()
plt.barh(x,y, color=my_colors,height=0.9, alpha=0.3)
plt.savefig('price_plot.png',bbox_inches="tight")

# %%
price_cat = pd.crosstab(index=playstore['Type'],
           columns='Jumlah').sort_values(by = 'Jumlah',ascending = False).head().reset_index()
price_cat.head()
# Out:
# col_0  Type  Jumlah
# 0      Free    8902
# 1      Paid     756

# %%
x = price_cat['Type'].values
y = price_cat['Jumlah'].values
my_colors = 'gbr'
fig = plt.figure(figsize=(6,3), dpi=300)
fig.add_subplot()
plt.bar(x,y, color=my_colors)
plt.savefig('price_cat.png',bbox_inches="tight")
